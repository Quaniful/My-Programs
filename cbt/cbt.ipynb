# %%
import pandas as pd

# %%
data = pd.read_csv('db.csv', index_col=['date', 'time'])
data
# Out:
#                                                           situation  \
# date       time
# 2020-07-25 21:55  Playing Overwatch with Bar, After sitting with...
#            15:38                                        Making food
# 2020-07-27 13:36  1 hour after waking up, drinking coffee, sat o...
#
#                                                            thoughts  \
# date       time
# 2020-07-25 21:55                                                NaN
#            15:38  Imagining myself speaking to Senya, Israeli ce...
# 2020-07-27 13:36  I should sit on my studies, theres an exam tom...
#
#                     emotional_response  emotional_intensity  \
# date       time
# 2020-07-25 21:55                   NaN                  NaN
#            15:38                   NaN                  NaN
# 2020-07-27 13:36  Overwhelmed, freezed                  2.0
#
#                                                   physical_response  \
# date       time
# ...
